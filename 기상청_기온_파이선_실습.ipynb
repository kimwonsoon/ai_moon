# %% [markdown]
# <a href="https://colab.research.google.com/github/kimwonsoon/ai_moon/blob/main/%EA%B8%B0%EC%83%81%EC%B2%AD_%EA%B8%B0%EC%98%A8_%ED%8C%8C%EC%9D%B4%EC%84%A0_%EC%8B%A4%EC%8A%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data=pd.read_csv('C:\\Users\\user\\OneDrive\\바탕 화면\\ta_20240309115200.csv'.encoding='cp949')
# Out:
#   File "<ipython-input-2-ce15ecdc0643>", line 2
#     data=pd.read_csv('C:\\Users\\user\\OneDrive\\바탕 화면\\ta_20240309115200.csv'.encoding='cp949')
#                      ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?

# %%
import pandas as pd
data = pd.read_csv('C:\\Users\\user\\OneDrive\\바탕 화면\\ta_20240309115200.csv', encoding='cp949')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-50e294a45bf7> in <cell line: 1>()
# ----> 1 data = pd.read_csv('C:\\Users\\user\\OneDrive\\바탕 화면\\ta_20240309115200.csv', encoding='cp949')
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# 파일 경로와 인코딩을 지정하여 CSV 파일 읽기
data = pd.read_csv('C:\\Users\\user\\OneDrive\\바탕 화면\\ta_20240309115200.csv', encoding='cp949')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-a6f0c041c90f> in <cell line: 4>()
#       2
#       3 # 파일 경로와 인코딩을 지정하여 CSV 파일 읽기
# ----> 4 data = pd.read_csv('C:\\Users\\user\\OneDrive\\바탕 화면\\ta_20240309115200.csv', encoding='cp949')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
import pandas as pd

# 파일 경로와 인코딩을 지정하여 CSV 파일 읽기
data = pd.read_csv('/content/ta_20240309115200.csv', encoding='cp949')

# %%
print(data.head())
# Out:
#              날짜  평균기온(℃)
# 0  \t2020-10-01     18.8
# 1  \t2020-10-02     19.2
# 2  \t2020-10-03     19.9
# 3  \t2020-10-04     16.6
# 4  \t2020-10-05     13.3

# %%
print(data['날짜']=='2020-10-01')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 403    False
# 404    False
# 405    False
# 406    False
# 407    False
# Name: 날짜, Length: 408, dtype: bool

# %%
print(data['날짜']=='2020-10-01')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 403    False
# 404    False
# 405    False
# 406    False
# 407    False
# Name: 날짜, Length: 408, dtype: bool

# %%
print(data[data['날짜']=='2020-10-10'])
# Out:
# Empty DataFrame
# Columns: [날짜, 평균기온(℃)]
# Index: []

# %%
print(data[data['날짜']=='2020-10-10'])
# Out:
# Empty DataFrame
# Columns: [날짜, 평균기온(℃)]
# Index: []

# %%
print(data['날짜'].str.endswith('11-01'))
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 403    False
# 404    False
# 405    False
# 406    False
# 407    False
# Name: 날짜, Length: 408, dtype: bool

# %%
print(data[data['날짜'].str.endswith('11-01')])
# Out:
#                날짜  평균기온(℃)
# 31   \t2020-11-01     13.7
# 396  \t2021-11-01     12.9

# %%
import matplotlib.pyplot as plt

# %%
x=data[data['날짜'].str.endswith('11-01')]['날짜']
y=data[data['날짜'].str.endswith('11-01')]['평균기온(℃)']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '평균기온(℃)'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
import pandas as pd

# Load the data into a DataFrame
data = pd.DataFrame({'날짜': ['2020-10-10', '2020-11-01', '2020-11-02', '2020-11-03'],
                   '평균기온': [10.5, 12.3, 13.1, 14.2]})

# Print the DataFrame
print(data)

# Select rows where the date column equals '2020-10-10'
print(data[data['날짜'] == '2020-10-10'])

# Select rows where the date column ends with '11-01'
print(data[data['날짜'].str.endswith('11-01')])

# Import matplotlib for plotting
import matplotlib.pyplot as plt

# Extract the date and average temperature for rows where the date column ends with '11-01'
x = data[data['날짜'].str.endswith('11-01')]['날짜']
y = data[data['날짜'].str.endswith('11-01')]['평균기온(℃)']

# Plot the data
plt.plot(x, y)
plt.show()
# Out:
#            날짜  평균기온
# 0  2020-10-10  10.5
# 1  2020-11-01  12.3
# 2  2020-11-02  13.1
# 3  2020-11-03  14.2
#            날짜  평균기온
# 0  2020-10-10  10.5
#            날짜  평균기온
# 1  2020-11-01  12.3
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %%
y = data[data['날짜'].str.endswith('11-01')]['평균기온']

# %%
plt.piot(x,y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-d5c21d04042b> in <cell line: 1>()
# ----> 1 plt.piot(x,y)
#       2 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'piot'

# %%
x = data[data['날짜'].str.endswith('11-01')]['날짜']
y = data[data['날짜'].str.endswith('11-01')]['평균기온']

# %%
plt.plot(x,y)
plt.xticks(rotation='45')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-2db23ec2d437> in <cell line: 2>()
#       1 plt.plot(x,y)
# ----> 2 plt.xticks(rotation='45')
#       3 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in xticks(ticks, labels, minor, **kwargs)
#    1889         labels = ax.get_xticklabels(minor=minor)
#    1890         for l in labels:
# -> 1891             l._internal_update(kwargs)
#    1892     else:
#    1893         labels = ax.set_xticklabels(labels, minor=minor, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in _internal_update(self, kwargs)
#    1221         The lack of prenormalization is to maintain backcompatibility.
#    1222         """
# -> 1223         return self._update_props(
#    1224             kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
# ...

# %%
import matplotlib.pyplot as plt

# x와 y 데이터를 정의 (이 부분을 실제 데이터로 채워야 합니다)

x = data[data['날짜'].str.endswith('11-01')]['날짜']
y = data[data['날짜'].str.endswith('11-01')]['평균기온(℃)']
# 선 그래프를 그림
plt.plot(x, y)

# x축 눈금 레이블을 45도 회전하여 표시
plt.xticks(rotation=45)

# 그래프 표시
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '평균기온(℃)'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# DataFrame 예시 (이 부분을 실제 데이터로 채워야 합니다)
df = pd.DataFrame({
    '날짜': ['2022-01-01', '2022-01-02', '2022-01-03'],
    '평균기온(℃)': [5, 7, 9]
})

# x와 y 데이터 선택
x = df['날짜']
  y = df['평균기온(℃)']
# Out:
#   File "<ipython-input-44-1b11eef5685f>", line 12
#     y = df['평균기온(℃)']
#     ^
# IndentationError: unexpected indent

# %%
plt.bar(df.index,df['날짜'],color='red')
plt.bar(df.index,df['평균기온'],color='blue')
plt.xticks(rotation=45)
plt.show()
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-2f39743f8b87> in <cell line: 1>()
# ----> 1 plt.bar(df.index,df['날짜'],color='red')
#       2 plt.bar(df.index,df['평균기온'],color='blue')
#       3 plt.xticks(rotation=45)
#       4 plt.show()
#       5 import matplotlib.pyplot as plt
#
# NameError: name 'df' is not defined

# %%
import matplotlib.pyplot as plt

# 'df' 변수를 정의하고 있다고 가정하고, 아래 코드를 실행합니다.
plt.bar(df.index, df['날짜'], color='red')
plt.bar(df.index, df['평균기온(℃)'], color='blue')
plt.xticks(rotation=45)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-02c0182cfcf1> in <cell line: 4>()
#       2
#       3 # 'df' 변수를 정의하고 있다고 가정하고, 아래 코드를 실행합니다.
# ----> 4 plt.bar(df.index, df['날짜'], color='red')
#       5 plt.bar(df.index, df['평균기온(℃)'], color='blue')
#       6 plt.xticks(rotation=45)
#
# NameError: name 'df' is not defined

# %%
# Import necessary modules
import matplotlib.pyplot as plt
import pandas as pd

# Load data into a DataFrame called 'df'
df = pd.read_csv('/content/ta_20240309115200.csv', encoding='cp949')

# Create the bar chart
plt.bar(df.index, df['날짜'], color='red')
plt.bar(df.index, df['평균기온(℃)'], color='blue')
plt.xticks(rotation=45)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=(10,10))
plt.barh(df.index,df['날짜'],color='red')
plt.barh(df.index,df['평균기온(℃)'],color='blue')
plt.show()
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,10))
x_range = np.arange(len(df))
plt.bar(x_range-0.2,df['날짜'],width=0.4,color='red')
plt.bar(x_range + 0.2, df['평균기온(℃)'], width=0.4, color='blue')
plt.xticks(rotation=45,ticks=x_range,labels=df.index)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-bbd06ee41ade> in <cell line: 2>()
#       1 plt.figure(figsize=(10,10))
# ----> 2 x_range = np.arange(len(df))
#       3 plt.bar(x_range-0.2,df['날짜'],width=0.4,color='red')
#       4 plt.bar(x_range + 0.2, df['평균기온(℃)'], width=0.4, color='blue')
#       5 plt.xticks(rotation=45,ticks=x_range,labels=df.index)
#
# NameError: name 'np' is not defined

# %%
import numpy as np
plt.figure(figsize=(10,10))
x_range = np.arange(len(df))
plt.bar(x_range-0.2,df['날짜'],width=0.4,color='red')
plt.bar(x_range + 0.2, df['평균기온(℃)'], width=0.4, color='blue')
plt.xticks(rotation=45,ticks=x_range,labels=df.index)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=(10,10))
x_range = np.arange(len(df))
plt.bar(x_range-0.2,df['날짜'],width=0.4,color='red')
plt.bar(x_range+0.2,df['평균기온(℃)'],width=0.4,color='blue')
plt.xticks(rotation=45,ticks=x_range,labels=df.index)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# DataFrame 예시 (이 부분을 실제 데이터로 채워야 합니다)
df = pd.DataFrame({
    '날짜': ['2022-01-01', '2022-01-02', '2022-01-03'],
    '평균기온(℃)': [5, 7, 9]
})

# x와 y 데이터 선택
x = df['날짜']
y = df['평균기온(℃)']

# 선 그래프를 그림
plt.plot(x, y)

# x축 눈금 레이블을 45도 회전하여 표시
plt.xticks(rotation=45)

# 그래프 표시
plt.show()
