# %% [markdown]
# <a href="https://colab.research.google.com/github/kimwonsoon/ai_moon/blob/main/%EA%B8%B0%EC%83%81%EC%B2%AD_%EB%82%A0%EC%94%A8%EB%8D%B0%EC%9D%B4%ED%84%B0_%EB%B6%84%EC%84%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data= pd.read_csv('09_data.csv,encoding='cp949')
# Out:
#   File "<ipython-input-3-9296ced50e43>", line 2
#     data= pd.read_csv('09_data.csv,encoding='cp949')
#                                                   ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
data = pd.read_csv('09_data.csv', encoding='cp949')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-e726aafa2920> in <cell line: 1>()
# ----> 1 data = pd.read_csv('09_data.csv', encoding='cp949')
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

data = pd.read_csv('09_data.csv', encoding='cp949')

# %%
print(data.dtypes)
# Out:
# 지점명        object
# 일시         object
# 기온(°C)    float64
# dtype: object

# %%
print(data.head())
# Out:
#   지점명               일시  기온(°C)
# 0  서울  2024-03-01 1:00    -0.4
# 1  서울  2024-03-01 2:00    -1.2
# 2  서울  2024-03-01 3:00    -1.9
# 3  서울  2024-03-01 4:00    -2.5
# 4  서울  2024-03-01 5:00    -2.8

# %%
print(data['지점명']=='서울')
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 283    False
# 284    False
# 285    False
# 286    False
# 287    False
# Name: 지점명, Length: 288, dtype: bool

# %%
is_seoul=data['지점명']=='서울'
seoul=data[is_seoul]
seoul
# Out:
#     지점명                일시  기온(°C)
# 0    서울   2024-03-01 1:00    -0.4
# 1    서울   2024-03-01 2:00    -1.2
# 2    서울   2024-03-01 3:00    -1.9
# 3    서울   2024-03-01 4:00    -2.5
# 4    서울   2024-03-01 5:00    -2.8
# ..   ..               ...     ...
# 139  서울  2024-03-06 20:00     7.2
# 140  서울  2024-03-06 21:00     6.1
# 141  서울  2024-03-06 22:00     5.1
# 142  서울  2024-03-06 23:00     4.6
# 143  서울   2024-03-07 0:00     4.2
#
# [144 rows x 3 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 50728 (\N{HANGUL SYLLABLE ON}) missing from current font.
#   plt.savefig(
# from matplotlib import pyplot as plt
# _df_1['기온(°C)'].plot(kind='hist', bins=20, title='기온(°C)')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 50728 (\N{HANGUL SYLLABLE ON}) missing from current font.
#   plt.savefig(
# from matplotlib import pyplot as plt
# _df_2.plot(kind='scatter', x='index', y='기온(°C)', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 50728 (\N{HANGUL SYLLABLE ON}) missing from current font.
#   plt.savefig(
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['기온(°C)']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_3.sort_values('index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('기온(°C)')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['index']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'index'}, axis=1)
#               .sort_values('index', ascending=True))
#   xs = counted['index']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_4.sort_values('index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_5['index'].plot(kind='line', figsize=(8, 4), title='index')
# plt.gca().spines[['top', 'right']].set_visible(False)
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 50728 (\N{HANGUL SYLLABLE ON}) missing from current font.
#   plt.savefig(
# from matplotlib import pyplot as plt
# _df_6['기온(°C)'].plot(kind='line', figsize=(8, 4), title='기온(°C)')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
busan=data[data['지점명']=='부산']
busan
# Out:
#     지점명                일시  기온(°C)
# 144  부산   2024-03-01 1:00     3.9
# 145  부산   2024-03-01 2:00     3.9
# 146  부산   2024-03-01 3:00     4.0
# 147  부산   2024-03-01 4:00     3.6
# 148  부산   2024-03-01 5:00     3.4
# ..   ..               ...     ...
# 283  부산  2024-03-06 20:00     6.3
# 284  부산  2024-03-06 21:00     6.0
# 285  부산  2024-03-06 22:00     5.6
# 286  부산  2024-03-06 23:00     5.5
# 287  부산   2024-03-07 0:00     5.5
#
# [144 rows x 3 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_7['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 50728 (\N{HANGUL SYLLABLE ON}) missing from current font.
#   plt.savefig(
# from matplotlib import pyplot as plt
# _df_8['기온(°C)'].plot(kind='hist', bins=20, title='기온(°C)')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 50728 (\N{HANGUL SYLLABLE ON}) missing from current font.
#   plt.savefig(
# from matplotlib import pyplot as plt
# _df_9.plot(kind='scatter', x='index', y='기온(°C)', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 50728 (\N{HANGUL SYLLABLE ON}) missing from current font.
#   plt.savefig(
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['기온(°C)']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_10.sort_values('index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('기온(°C)')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['index']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'index'}, axis=1)
#               .sort_values('index', ascending=True))
#   xs = counted['index']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_11.sort_values('index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_12['index'].plot(kind='line', figsize=(8, 4), title='index')
# plt.gca().spines[['top', 'right']].set_visible(False)
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 50728 (\N{HANGUL SYLLABLE ON}) missing from current font.
#   plt.savefig(
# from matplotlib import pyplot as plt
# _df_13['기온(°C)'].plot(kind='line', figsize=(8, 4), title='기온(°C)')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
temp=[]
for i in seoul['일시']:
  temp.append(i.split('')[0])
lack_seoul=[]
unique_temp=set(temp)
fori in unique_temp
    if temp.count(i)!=24:
      lack_seoul.append(i)
print(lack_seoul)
# Out:
#   File "<ipython-input-15-d1f169a0c1f9>", line 7
#     if temp.count(i)!=24:
#     ^
# IndentationError: unexpected indent

# %%
temp=[]
for i in seoul['일시']:
    temp.append(i.split(' ')[0])
lack_seoul=[]
unique_temp=set(temp)
for i in unique_temp:
    if temp.count(i)!=24:
        lack_seoul.append(i)
print(lack_seoul)
# Out:
# ['2024-03-07', '2024-03-01']

# %%
temp=[]
for i in seoul['일시']:
    temp.append(i.split(' ')[0])
lack_busan=[]
unique_temp=set(temp)
for i in unique_temp:
    if temp.count(i)!=24:
        lack_busan.append(i)
print(lack_busan)
# Out:
# ['2024-03-07', '2024-03-01']

# %%
lack_data = list(set(lack_seoul+lack_busan))
for i in lack_data:
    seoul = seoul[seoul['일시'].str.split(' ').str[0] != i]
    busan = busan[busan['일시'].str.split(' ').str[0] != i]

# %%
print(len(seoul))
print(len(busan))
# Out:
# 120
# 120

# %%
for i in lack_busan:
    busan = busan[busan['일시'].str.split(' ').str[0] != i]
busan
# Out:
#     지점명                일시  기온(°C)
# 167  부산   2024-03-02 0:00    -1.9
# 168  부산   2024-03-02 1:00    -2.7
# 169  부산   2024-03-02 2:00    -3.3
# 170  부산   2024-03-02 3:00    -3.7
# 171  부산   2024-03-02 4:00    -4.3
# ..   ..               ...     ...
# 282  부산  2024-03-06 19:00     6.8
# 283  부산  2024-03-06 20:00     6.3
# 284  부산  2024-03-06 21:00     6.0
# 285  부산  2024-03-06 22:00     5.6
# 286  부산  2024-03-06 23:00     5.5
#
# [120 rows x 3 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_14['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 50728 (\N{HANGUL SYLLABLE ON}) missing from current font.
#   plt.savefig(
# from matplotlib import pyplot as plt
# _df_15['기온(°C)'].plot(kind='hist', bins=20, title='기온(°C)')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 50728 (\N{HANGUL SYLLABLE ON}) missing from current font.
#   plt.savefig(
# from matplotlib import pyplot as plt
# _df_16.plot(kind='scatter', x='index', y='기온(°C)', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 50728 (\N{HANGUL SYLLABLE ON}) missing from current font.
#   plt.savefig(
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['기온(°C)']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_17.sort_values('index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('기온(°C)')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['index']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'index'}, axis=1)
#               .sort_values('index', ascending=True))
#   xs = counted['index']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_18.sort_values('index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_19['index'].plot(kind='line', figsize=(8, 4), title='index')
# plt.gca().spines[['top', 'right']].set_visible(False)
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 50728 (\N{HANGUL SYLLABLE ON}) missing from current font.
#   plt.savefig(
# from matplotlib import pyplot as plt
# _df_20['기온(°C)'].plot(kind='line', figsize=(8, 4), title='기온(°C)')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
import numpy as np
time=['0:00','1:00','2:00','3:00','4:00','5:00','6:00','7:00','8:00','9:00','10:00','11:00','12:00',
     '13:00','14:00','15:00','16:00','17:00','18:00','19:00','20:00','21:00','22:00','23:00']
zeros = np.zeros((24,2))
df = pd.DataFrame(zeros,index=time,columns=['seoul','busan'])

# %%
df
# Out:
#        seoul  busan
# 0:00     0.0    0.0
# 1:00     0.0    0.0
# 2:00     0.0    0.0
# 3:00     0.0    0.0
# 4:00     0.0    0.0
# 5:00     0.0    0.0
# 6:00     0.0    0.0
# 7:00     0.0    0.0
# 8:00     0.0    0.0
# 9:00     0.0    0.0
# 10:00    0.0    0.0
# 11:00    0.0    0.0
# 12:00    0.0    0.0
# 13:00    0.0    0.0
# 14:00    0.0    0.0
# 15:00    0.0    0.0
# 16:00    0.0    0.0
# 17:00    0.0    0.0
# 18:00    0.0    0.0
# 19:00    0.0    0.0
# 20:00    0.0    0.0
# 21:00    0.0    0.0
# 22:00    0.0    0.0
# 23:00    0.0    0.0
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['seoul']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'seoul'}, axis=1)
#               .sort_values('seoul', ascending=True))
#   xs = counted['seoul']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_21.sort_values('seoul', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('seoul')
# _ = plt.ylabel('count()')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['busan']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'busan'}, axis=1)
#               .sort_values('busan', ascending=True))
#   xs = counted['busan']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_22.sort_values('busan', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('busan')
# _ = plt.ylabel('count()')

# %%
for i in range(0,len(seoul),24):
    print(seoul.iloc[i:i+24])
# Out:
#    지점명                일시  기온(°C)
# 23  서울   2024-03-02 0:00    -7.1
# 24  서울   2024-03-02 1:00    -7.4
# 25  서울   2024-03-02 2:00    -7.7
# 26  서울   2024-03-02 3:00    -8.0
# 27  서울   2024-03-02 4:00    -8.0
# 28  서울   2024-03-02 5:00    -8.0
# 29  서울   2024-03-02 6:00    -7.9
# 30  서울   2024-03-02 7:00    -8.0
# 31  서울   2024-03-02 8:00    -7.4
# 32  서울   2024-03-02 9:00    -4.2
# 33  서울  2024-03-02 10:00    -2.1
# 34  서울  2024-03-02 11:00     0.2
# 35  서울  2024-03-02 12:00     1.9
# 36  서울  2024-03-02 13:00     2.2
# 37  서울  2024-03-02 14:00     2.9
# 38  서울  2024-03-02 15:00     3.2
# 39  서울  2024-03-02 16:00     3.1
# 40  서울  2024-03-02 17:00     3.7
# 41  서울  2024-03-02 18:00     3.4
# 42  서울  2024-03-02 19:00     3.5
# 43  서울  2024-03-02 20:00     3.3
# 44  서울  2024-03-02 21:00     3.3
# 45  서울  2024-03-02 22:00     3.4
# 46  서울  2024-03-02 23:00     3.4
#    지점명                일시  기온(°C)
# 47  서울   2024-03-03 0:00     4.1
# 48  서울   2024-03-03 1:00     4.2
# 49  서울   2024-03-03 2:00     4.1
# 50  서울   2024-03-03 3:00     3.5
# 51  서울   2024-03-03 4:00     2.4
# 52  서울   2024-03-03 5:00     1.5
# 53  서울   2024-03-03 6:00     0.9
# 54  서울   2024-03-03 7:00     0.5
# 55  서울   2024-03-03 8:00     0.7
# 56  서울   2024-03-03 9:00     2.0
# 57  서울  2024-03-03 10:00     3.5
# 58  서울  2024-03-03 11:00     4.9
# 59  서울  2024-03-03 12:00     6.7
# 60  서울  2024-03-03 13:00     7.3
# 61  서울  2024-03-03 14:00     7.3
# 62  서울  2024-03-03 15:00     7.3
# 63  서울  2024-03-03 16:00     7.2
# 64  서울  2024-03-03 17:00     6.8
# 65  서울  2024-03-03 18:00     6.0
# 66  서울  2024-03-03 19:00     5.0
# 67  서울  2024-03-03 20:00     4.4
# 68  서울  2024-03-03 21:00     3.6
# 69  서울  2024-03-03 22:00     2.9
# 70  서울  2024-03-03 23:00     2.5
#    지점명                일시  기온(°C)
# 71  서울   2024-03-04 0:00     1.8
# 72  서울   2024-03-04 1:00     1.4
# 73  서울   2024-03-04 2:00     0.9
# 74  서울   2024-03-04 3:00     0.4
# 75  서울   2024-03-04 4:00    -0.2
# 76  서울   2024-03-04 5:00    -0.6
# 77  서울   2024-03-04 6:00    -1.3
# 142  서울  2024-03-06 23:00     4.6

# %%
max_idx = []
for i in range(0,len(seoul),24):
    max_idx.append(seoul.iloc[i:i+24,2].idxmax())
for i in max_idx:
    df.loc[seoul.loc[i][1].split(' ')[1]]['seoul'] +=1

# %%
max_idx = []
for i in range(0,len(busan),24):
    max_idx.append(busan.iloc[i:i+24,2].idxmax())
for i in max_idx:
    df.loc[busan.loc[i][1].split(' ')[1]]['busan'] +=1

# %%
df
# Out:
#        seoul  busan
# 0:00     0.0    1.0
# 1:00     0.0    0.0
# 2:00     0.0    0.0
# 3:00     0.0    0.0
# 4:00     0.0    0.0
# 5:00     0.0    0.0
# 6:00     0.0    0.0
# 7:00     0.0    0.0
# 8:00     0.0    0.0
# 9:00     0.0    0.0
# 10:00    0.0    0.0
# 11:00    0.0    0.0
# 12:00    0.0    1.0
# 13:00    1.0    0.0
# 14:00    1.0    0.0
# 15:00    2.0    1.0
# 16:00    0.0    2.0
# 17:00    1.0    0.0
# 18:00    0.0    0.0
# 19:00    0.0    0.0
# 20:00    0.0    0.0
# 21:00    0.0    0.0
# 22:00    0.0    0.0
# 23:00    0.0    0.0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_23['seoul'].plot(kind='hist', bins=20, title='seoul')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_24['busan'].plot(kind='hist', bins=20, title='busan')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_25.plot(kind='scatter', x='seoul', y='busan', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_26['seoul'].plot(kind='line', figsize=(8, 4), title='seoul')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_27['busan'].plot(kind='line', figsize=(8, 4), title='busan')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
df.plot()
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

plt.bar(df.index,df['seoul'],color='red')
plt.bar(df.index,df['busan'],color='blue')
plt.xticks(rotation=45)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,10))
plt.barh(df.index,df['seoul'],color='red')
plt.barh(df.index,df['busan'],color='blue')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,10))
plt.bar(df.index,df['seoul'],color='red')
plt.plot(df.index,df['busan'],color='blue')
plt.xticks(rotation=45)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(10,10))
x_range = np.arange(len(df))
plt.bar(x_range-0.2,df['seoul'],width=0.4,color='red')
plt.bar(x_range+0.2,df['busan'],width=0.4,color='blue')
plt.xticks(rotation=45,ticks=x_range,labels=df.index)
plt.show()

# %%
import numpy as np
time=['0:00','1:00','2:00','3:00','4:00','5:00','6:00','7:00','8:00','9:00','10:00','11:00','12:00',
     '13:00','14:00','15:00','16:00','17:00','18:00','19:00','20:00','21:00','22:00','23:00']
zeros = np.zeros((24,2))
df = pd.DataFrame(zeros,index=time,columns=['seoul','busan'])

min_idx = []
for i in range(0,len(seoul),24):
    min_idx.append(seoul.iloc[i:i+24,2].idxmin())
for i in min_idx:
    df.loc[seoul.loc[i][1].split(' ')[1]]['seoul'] +=1

min_idx = []
for i in range(0,len(busan),24):
    min_idx.append(busan.iloc[i:i+24,2].idxmin())
for i in min_idx:
    df.loc[busan.loc[i][1].split(' ')[1]]['busan'] +=1

import matplotlib.pyplot as plt

plt.figure(figsize=(10,10))
x_range = np.arange(len(df))
plt.bar(x_range-0.2,df['seoul'],width=0.4,color='red')
plt.bar(x_range+0.2,df['busan'],width=0.4,color='blue')
plt.xticks(rotation=45,ticks=x_range,labels=df.index)
plt.show()
